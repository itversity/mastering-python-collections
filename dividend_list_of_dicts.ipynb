# %% [markdown]
# ## Get dividend list of dicts by Non-zero and zero values seperatley
#
# * Develop a code to get list of dicts having Non-zero dividend values and zero dividend values seperately
# * You can use Loops or functions like Map, Filter etc..

# %%
companies = [{'Company_name':'Accenture', 'Sector':'IT', 'Price':'222.89', 'Dividend':'2.33', 'Share':'7.92'},
             {'Company_name':'Apple', 'Sector':'IT', 'Price':'155.15', 'Dividend':'1.57', 'Share':'9.2'},
             {'Company_name':'Adobe Systems Inc', 'Sector':'IT', 'Price':'185.16', 'Dividend':'0', 'Share':'3.39'},
             {'Company_name':'Alphabet', 'Sector':'IT', 'Price':'1007.71', 'Dividend':'0', 'Share':'22.27'},
             {'Company_name':'Bank of America Corp', 'Sector':'Finacials', 'Price':'29.74', 'Dividend':'1.53', 'Share':'1.55'},
             {'Company_name':'Biogen Inc', 'Sector':'Health Care', 'Price':'311.79', 'Dividend':'0', 'Share':'11.94'},
             {'Company_name':'Campbell Soup', 'Sector':'Consumer Staples', 'Price':'44.83', 'Dividend':'3.12', 'Share':'2.89'},
             {'Company_name':'Dr Pepper Snapple Group', 'Sector':'Consumer Staples', 'Price':'116.93', 'Dividend':'1.96', 'Share':'4.54'},
             {'Company_name':'ebay Inc', 'Sector':'IT', 'Price':'41.02', 'Dividend':'0', 'Share':'-1.07'},
             {'Company_name':'FedEx Corporation', 'Sector':'Industrials', 'Price':'239.27', 'Dividend':'0.79', 'Share':'11.07'},
             {'Company_name':'Ford Motors', 'Sector':'Consumer Products', 'Price':'10.43', 'Dividend':'6.78', 'Share':'1.9'},
             {'Company_name':'General Motors', 'Sector':'Consumer Products', 'Price':'40.75', 'Dividend':'3.58', 'Share':'6'},
             {'Company_name':'Harley-Davidson', 'Sector':'Consumer Products', 'Price':'47.54', 'Dividend':'3.02', 'Share':'2.98'},
             {'Company_name':'Hewlett Packard Enterprise', 'Sector':'IT', 'Price':'15.04', 'Dividend':'1.92', 'Share':'0.21'},
             {'Company_name':'Intel Corp', 'Sector':'IT', 'Price':'42.75', 'Dividend':'2.65', 'Share':'1.98'},
             {'Company_name':'JP Morgan', 'Sector':'Finacials', 'Price':'107.88', 'Dividend':'1.98', 'Share':'6.3'},
             {'Company_name':'Johnson & Johnson', 'Sector':'IT', 'Price':'126.36', 'Dividend':'2.55', 'Share':'0.39'},
             {'Company_name':'Microsoft Corp', 'Sector':'IT', 'Price':'85.01', 'Dividend':'1.87', 'Share':'2.97'},
             {'Company_name':'Netflix Inc', 'Sector':'IT', 'Price':'250.01', 'Dividend':'0', 'Share':'1.25'},
             {'Company_name':'Nike', 'Sector':'Consumer Products', 'Price':'62.49', 'Dividend':'1.21', 'Share':'2.51'}]

# %%
def get_dividend_values(companies):
##your code should go here
    return

# %%
get_dividend_values(companies)

# %% [markdown]
# ## The desired ouput is
# ```python
# {'List of dicts with non-zero dividend values': [{'Company_name': 'Accenture',
#    'Sector': 'IT',
#    'Price': '222.89',
#    'Dividend': '2.33',
#    'Share': '7.92'},
#   {'Company_name': 'Apple',
#    'Sector': 'IT',
#    'Price': '155.15',
#    'Dividend': '1.57',
#    'Share': '9.2'},
#   {'Company_name': 'Adobe Systems Inc',
#    'Sector': 'IT',
#    'Price': '185.16',
#    'Dividend': '0',
#    'Share': '3.39'},
#   {'Company_name': 'Alphabet',
#    'Sector': 'IT',
#    'Price': '1007.71',
#    'Dividend': '0',
#    'Share': '22.27'},
#   {'Company_name': 'Bank of America Corp',
#    'Sector': 'Finacials',
#    'Price': '29.74',
#    'Dividend': '1.53',
#    'Share': '1.55'},
#   {'Company_name': 'Biogen Inc',
#    'Sector': 'Health Care',
#    'Price': '311.79',
#    'Dividend': '0',
#    'Share': '11.94'},
#   {'Company_name': 'Campbell Soup',
#    'Sector': 'Consumer Staples',
#    'Price': '44.83',
#    'Dividend': '3.12',
#    'Share': '2.89'},
#   {'Company_name': 'Dr Pepper Snapple Group',
#    'Sector': 'Consumer Staples',
#    'Price': '116.93',
#    'Dividend': '1.96',
#    'Share': '4.54'},
#   {'Company_name': 'ebay Inc',
#    'Sector': 'IT',
#    'Price': '41.02',
#    'Dividend': '0',
#    'Share': '-1.07'},
#   {'Company_name': 'FedEx Corporation',
#    'Sector': 'Industrials',
#    'Price': '239.27',
#    'Dividend': '0.79',
#    'Share': '11.07'},
#   {'Company_name': 'Ford Motors',
#    'Sector': 'Consumer Products',
#    'Price': '10.43',
#    'Dividend': '6.78',
#    'Share': '1.9'},
#   {'Company_name': 'General Motors',
#    'Sector': 'Consumer Products',
#    'Price': '40.75',
#    'Dividend': '3.58',
#    'Share': '6'},
#   {'Company_name': 'Harley-Davidson',
#    'Sector': 'Consumer Products',
#    'Price': '47.54',
#    'Dividend': '3.02',
#    'Share': '2.98'},
#   {'Company_name': 'Hewlett Packard Enterprise',
#    'Sector': 'IT',
#    'Price': '15.04',
#    'Dividend': '1.92',
#    'Share': '0.21'},
#   {'Company_name': 'Intel Corp',
#    'Sector': 'IT',
#    'Price': '42.75',
#    'Dividend': '2.65',
#    'Share': '1.98'},
#   {'Company_name': 'JP Morgan',
#    'Sector': 'Finacials',
#    'Price': '107.88',
#    'Dividend': '1.98',
#    'Share': '6.3'},
#   {'Company_name': 'Johnson & Johnson',
#    'Sector': 'IT',
#    'Price': '126.36',
#    'Dividend': '2.55',
#    'Share': '0.39'},
#   {'Company_name': 'Microsoft Corp',
#    'Sector': 'IT',
#    'Price': '85.01',
#    'Dividend': '1.87',
#    'Share': '2.97'},
#   {'Company_name': 'Netflix Inc',
#    'Sector': 'IT',
#    'Price': '250.01',
#    'Dividend': '0',
#    'Share': '1.25'},
#   {'Company_name': 'Nike',
#    'Sector': 'Consumer Products',
#    'Price': '62.49',
#    'Dividend': '1.21',
#    'Share': '2.51'}],
#  'List of dicts with zero dividend values': [{'Company_name': 'Adobe Systems Inc',
#    'Sector': 'IT',
#    'Price': '185.16',
#    'Dividend': '0',
#    'Share': '3.39'},
#   {'Company_name': 'Alphabet',
#    'Sector': 'IT',
#    'Price': '1007.71',
#    'Dividend': '0',
#    'Share': '22.27'},
#   {'Company_name': 'Biogen Inc',
#    'Sector': 'Health Care',
#    'Price': '311.79',
#    'Dividend': '0',
#    'Share': '11.94'},
#   {'Company_name': 'ebay Inc',
#    'Sector': 'IT',
#    'Price': '41.02',
#    'Dividend': '0',
#    'Share': '-1.07'},
#   {'Company_name': 'Netflix Inc',
#    'Sector': 'IT',
#    'Price': '250.01',
#    'Dividend': '0',
#    'Share': '1.25'}]}
# ```
